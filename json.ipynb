# %%
import numpy as np
import random
import json
import time
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
a = {}
m = 10
for i in range(m): 
    a[i]={'name':1,
          'description':'NFT of the 2nd highest peak of the Annapurna mountain range and the 16th highest peak in the world. The elevation of the peak is 7,937 m.',
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/1.jpg',
          'edition': i,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Blue'},
                 {'trait_type':'Climbers','value':'15'},
                 {'trait_type':'Elevation','value':'7,939 M'},
                 {'trait_type':'First ascent','value':'1960'},
                 {'trait_type':'Location','value':'Central Nepal'}],
         'compiler':'Shreeya'}
    a[i+1]={'name':2,
          'description':'NFT of the tenth highest mountain in the world. The mountain is well known for the difficulty and danger involved in its ascent.',
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/2.jpg',
          'edition': i+1,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Blue'},
                 {'trait_type':'Climbers','value':'191'},
                 {'trait_type':'Elevation','value':'8,091 M'},
                 {'trait_type':'First ascent','value':'1950'},
                 {'trait_type':'Location','value':'North Central Nepal'}],
         'compiler':'Shreeya'}
    a[i+1+1]={'name':3,
          'description':"'NFT of the sixth-highest mountain in the world. The English translation of Cho Oyu means 'Turquoise Goddess'.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/3.jpg',
          'edition': i+1+1,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Blue'},
                 {'trait_type':'Climbers','value':'262'},
                 {'trait_type':'Elevation','value':'8,188 M'},
                 {'trait_type':'First ascent','value':'1954'},
                 {'trait_type':'Location','value':'China-Nepal Border'}],
         'compiler':'Shreeya'}
    a[i+1+1+1]={'name':4,
          'description':"NFT of the fifteenth-highest peak in the world. Gyanchung Kang is the highest peak that is not in the eight thousand metres tall category.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/4.jpg',
          'edition': i+1+1+1,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Light Blue'},
                 {'trait_type':'Climbers','value':'26'},
                 {'trait_type':'Elevation','value':'7,952 M'},
                 {'trait_type':'First ascent','value':'1964'},
                 {'trait_type':'Location','value':'Nepal and China Border'}],
         'compiler':'Shreeya'}
    a[i+1+1+1+1]={'name':5,
          'description':"NFT of the third highest mountain in the world. It was assumed to be the highest mountain in the world until 1852.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/5.jpg',
          'edition': i+1+1+1+1,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Blue'},
                 {'trait_type':'Climbers','value':'243'},
                 {'trait_type':'Elevation','value':'8,586 M'},
                 {'trait_type':'First ascent','value':'1955'},
                 {'trait_type':'Location','value':'Sikkim-Nepal Border'}],
         'compiler':'Shreeya'}
    a[i+5]={'name':6,
          'description':"NFT of the fourth highest mountain in the world after Mount Everest, K2, and Kangchenjunga.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/6.jpg',
          'edition': i+5,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'White'},
                 {'trait_type':'Climbers','value':'371'},
                 {'trait_type':'Elevation','value':'8,516 M'},
                 {'trait_type':'First ascent','value':'1956'},
                 {'trait_type':'Location','value':'Nepal-China Border'}],
         'compiler':'Shreeya'}
    a[i+6]={'name':7,
          'description':"NFT of the Machhapuchre mountain in Nepal. The highest peak of the mountain has never been climbed due to its complex structure.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/7.jpg',
          'edition': i+6,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Lavender'},
                 {'trait_type':'Climbers','value':'0'},
                 {'trait_type':'Elevation','value':'6,993 M'},
                 {'trait_type':'First ascent','value':'1957'},
                 {'trait_type':'Location','value':'North-central Nepal'}],
         'compiler':'Shreeya'}
    a[i+7]={'name':8,
          'description':"NFT of the fifth highest mountain in the world. The shape of the mountain is a four-sided pyramid.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/8.jpg',
          'edition': i+7,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Gradient Blue'},
                 {'trait_type':'Climbers','value':'297'},
                 {'trait_type':'Elevation','value':'8,463 M'},
                 {'trait_type':'First ascent','value':'1956'},
                 {'trait_type':'Location','value':'Nepal-China Border'}],
         'compiler':'Shreeya'}              
    a[i+8]={'name':9,
          'description':"NFT of the eighth-highest mountain in the world.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/9.jpg',
          'edition': i+8,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Dark Blue'},
                 {'trait_type':'Climbers','value':'297'},
                 {'trait_type':'Elevation','value':'8,163 M'},
                 {'trait_type':'First ascent','value':'1956'},
                 {'trait_type':'Location','value':'Southeast of Mount Everest'}],
         'compiler':'Shreeya'}  
    a[i+9]={'name':10,
          'description':"NFT of the highest peak in the world.",
          'image':'ipfs://QmWhqXX1MmJst6K4RvwhVQWrVphWzjRGRM4xx26MW7DPMX/10.jpg',
          'edition': i+9,
          'date':time.time(),
          'attributes':[{'trait_type':'Background','value':'Blue'},
                 {'trait_type':'Climbers','value':'5,294'},
                 {'trait_type':'Elevation','value':'8,848.86 M'},
                 {'trait_type':'First ascent','value':'1953'},
                 {'trait_type':'Location','value':'Sagarmatha, Nepal'}],
         'compiler':'Shreeya'}   
    break

# %%
for k in range(m):
    with open('1.json', 'w') as fp:
        json.dump(a[k], fp)
    with open('2.json', 'w') as fp:
        json.dump(a[k+1], fp)
    with open('3.json', 'w') as fp:
        json.dump(a[k+2], fp)
    with open('4.json', 'w') as fp:
        json.dump(a[k+3], fp)
    with open('5.json', 'w') as fp:
        json.dump(a[k+4], fp)
    with open('6.json', 'w') as fp:
        json.dump(a[k+5], fp)
    with open('7.json', 'w') as fp:
        json.dump(a[k+6], fp)
    with open('8.json', 'w') as fp:
        json.dump(a[k+7], fp)
    with open('9.json', 'w') as fp:
        json.dump(a[k+8], fp)
    with open('10.json', 'w') as fp:
        json.dump(a[k+9], fp)
    break
